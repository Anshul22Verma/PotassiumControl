# %%
! pip install huggingface-hub

# %%
! pip install datasets

# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# %%
import os
from unsloth import FastLanguageModel
import torch
from trl import SFTTrainer  # trainer for supervised fine-tuning (SFT)
from unsloth import is_bfloat16_supported  # checks if the hardware supports bfloat16 operations

from huggingface_hub import login
from transformers import TrainingArguments
from datasets import load_dataset  # Lets you load fine-tuning datasets in huggingface


os.environ["HF_TOKEN"] = "***"
hugging_face_token = os.environ["HF_TOKEN"]
login(hugging_face_token)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# paramerts to load pre-trained model
max_seq_length = 1024  # Define the maximum sequence length a model can handle (i.e. how many tokens can be processed at once)
dtype = None  # set to default
load_in_4bit = True  # Enables 4-bit quantization - a memory saving optimization


model_og, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/DeepSeek-R1-Distill-Qwen-1.5B",
    max_seq_length = max_seq_length,
    dtype = None,
    load_in_4bit = True,
)

# Do model patching and add fast LoRA weights
model = FastLanguageModel.get_peft_model(
    model_og,
    r = 64,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 128,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    max_seq_length = max_seq_length,
    use_rslora = True,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)


# Load the R1 model and tokenizer using unsloth - imported using FastLanguageModel
# model_og, tokenizer = FastLanguageModel.from_pretrained(
#     model_name="unsloth/DeepSeek-R1-Distill-Qwen-1.5B",  # ref: https://huggingface.co/unsloth/DeepSeek-R1
#     max_seq_length=max_seq_length,
#     dtype=dtype,
#     load_in_4bit=load_in_4bit,
#     token=hugging_face_token
# )
# Out:
# ==((====))==  Unsloth 2025.3.1: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/1.81G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/6.78k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Unsloth 2025.3.1 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %%
prompt_style = """Given a end stage Heart Failue patient's on Mineralocorticoid receptor antagonists (MRAs) meal log
provide dietary feedback to the patients think and try to provide the question,
- Patients on MRAs need to control their potassium
- Patients with end stage heart failure need to control their sodium (salt), fluid, minerals, and fat.
- Be concise and to the point the recommendations should come from patient's meal log.
- Cant drink a lot of water because end stage Heart Failue need to control their fluid.

### Meal Log:
{}


### Response:
<think>{}"""

# %%
question = "9:00 AM - Grits with butter, 1:00 PM - Fried chicken with collard greens, 7:00 PM - Sweet potato pie."
FastLanguageModel.for_inference(model_og)
inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")
# generate response using the model
outputs = model_og.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    use_cache=True
)
# decode the generated output tokens into human-readable text
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])

# %%
# use supervised fine-tuning with training prompts and existing thinking
train_prompt_style = """Given a end stage Heart Failue patient's on Mineralocorticoid receptor antagonists (MRAs) meal log
provide dietary feedback to the patients think and try to provide the question,
- Patients on MRAs need to control their potassium
- Patients with end stage heart failure need to control their sodium (salt), fluid, minerals, and fat.
- Be concise and to the point the recommendations should come from patient's meal log.
- Cant drink a lot of water because end stage Heart Failue need to control their fluid.

### Meal Log:
{}

### Response (Dietician Recommendation):
<think>
{}
</think>
{}"""

EOS_TOKEN = tokenizer.eos_token  # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    inputs = examples["meal_log"]
    cots = examples["nutrition_diagnosis"]
    outputs = examples["follow_up_recommendations"]
    texts = []
    for input, cot, output in zip(inputs, cots, outputs):
        text = train_prompt_style.format(input, cot, output) + EOS_TOKEN
        texts.append(text)
    return {
        "text": texts,
    }

# %%
from datasets import load_dataset
# Load dataset from a local JSONL file
# dataset = load_dataset("json", data_files="dummy_coldstart.jsonl")

import json
from datasets import Dataset

def load_custom_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)

    meal_logs = []
    follow_up_recommendations = []
    nutrition_diagnosis = []

    for sample in data.values():
        meal_logs.append(sample["meal_log"])
        # print(sample.keys())
        follow_up_recommendations.append(sample["follow_up_recommendations"])
        nutrition_diagnosis.append(sample["nutrition_diagnosis"])
    return Dataset.from_dict({"meal_log": meal_logs, "nutrition_diagnosis": nutrition_diagnosis, "follow_up_recommendations": follow_up_recommendations})

# Load your custom JSON file
file_path = "gmdt_synthetic_data.json" #change to your file name
dataset = load_custom_json(file_path)

# Access the dataset split (default is 'train' if no split is defined)
print(dataset)
dataset = dataset.map(formatting_prompts_func, batched = True,)

model = FastLanguageModel.get_peft_model(
    model_og,
    r=8,
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",  # True or "unsloth" for very long context
    random_state=2025,
    use_rslora=False,
    loftq_config=None,
)
# Out:
# Dataset({
#     features: ['meal_log', 'nutrition_diagnosis', 'follow_up_recommendations'],
#     num_rows: 1026
# })
# Map:   0%|          | 0/1026 [00:00<?, ? examples/s]

# %%
dataset = dataset.train_test_split(test_size=0.1)

# %%
dataset["train"][0]
# Out:
# {'meal_log': '11:30 AM - 1 cup Greek yogurt, 1/4 cup strawberries. 2:30 PM - 4 oz grilled chicken salad (mixed greens, cucumber, olive oil dressing). 8:30 PM - 4 oz baked cod, 1 cup steamed asparagus.',
#  'nutrition_diagnosis': 'Potential for excessive potassium from strawberries.',
#  'follow_up_recommendations': '1. Limit strawberries to 1/4 cup 3 times weekly. 2. Monitor potassium levels. 3. Use olive oil moderately. 4. Read nutrition labels.',
#  'text': "Given a end stage Heart Failue patient's on Mineralocorticoid receptor antagonists (MRAs) meal log \nprovide dietary feedback to the patients think and try to provide the question,\n- Patients on MRAs need to control their potassium\n- Patients with end stage heart failure need to control their sodium (salt), fluid, minerals, and fat.\n- Be concise and to the point the recommendations should come from patient's meal log.\n- Cant drink a lot of water because end stage Heart Failue need to control their fluid.\n\n### Meal Log:\n11:30 AM - 1 cup Greek yogurt, 1/4 cup strawberries. 2:30 PM - 4 oz grilled chicken salad (mixed greens, cucumber, olive oil dressing). 8:30 PM - 4 oz baked cod, 1 cup steamed asparagus.\n\n### Response (Dietician Recommendation):\n<think>\nPotential for excessive potassium from strawberries.\n</think>\n1. Limit strawberries to 1/4 cup 3 times weekly. 2. Monitor potassium levels. 3. Use olive oil moderately. 4. Read nutrition labels.<｜end▁of▁sentence｜>"}

# %%
# pip install --upgrade transformers peft

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

# %%
import transformers
import peft

print(f"Transformers version: {transformers.__version__}")
print(f"PEFT version: {peft.__version__}")
# Out:
# Transformers version: 4.49.0
# PEFT version: 0.14.0

# %%
model_og, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/DeepSeek-R1-Distill-Qwen-1.5B",
    max_seq_length = max_seq_length,
    dtype = None,
    load_in_4bit = True,
)

# Do model patching and add fast LoRA weights
model = FastLanguageModel.get_peft_model(
    model_og,
    r = 64,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 128,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    max_seq_length = max_seq_length,
    use_rslora = True,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset['train'],
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        # Use num_train_epochs = 1, warmup_ratio for full training runs!
        warmup_steps=5,
        max_steps=2500,
        learning_rate=2e-4,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=100,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
    ),
    report_to="none"
)

trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth 2025.3.1: Fast Qwen2 patching. Transformers: 4.49.0.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Converting train dataset to ChatML (num_proc=2):   0%|          | 0/923 [00:00<?, ? examples/s]
# Applying chat template to train dataset (num_proc=2):   0%|          | 0/923 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=2):   0%|          | 0/923 [00:00<?, ? examples/s]
# Truncating train dataset (num_proc=2):   0%|          | 0/923 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 923 | Num Epochs = 22
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 2,500
#  "-____-"     Number of trainable parameters = 73,859,072
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 1:16:47, Epoch 21/22]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.432600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.175300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.133300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.102000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.086000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.074300</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.064100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.055800</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.047100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.042700</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.038700</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.035900</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.034000</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.032900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.031400</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.030600</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.030700</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.029700</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.029100</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.028600</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.028300</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.027900</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.027100</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.027000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.026500</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
question = "B: coffee x2 with cream and sugar cranberry almond crunch cereal (1 cup) w 1 cup 2% milk or instant apple cinnamon porridge made with water and milk added or toast with pb and jam and 100 g source yogurt no lunch but snacks on jelly beans, jell0, plain dads oatmeal cookies, lots of grapes or potato chips D: pork chops, sausages, chx, with sweet or white potato and frozen vegetables-variety; frozen fish and chips; grill cheese with tomato soup 9 pm snack-ice cream +/- jello or brownies or coconut bowl or pb cookies or cupcakes or oatmeal banana cookies"


FastLanguageModel.for_inference(model)  # Unsloth has 2x faster inference!
inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# <think>
# High sodium, saturated fat, potassium, and sugar intake.
# </think>
# 1. Use low-sodium soy sauce or eliminate it from meals. 2. Use lean pork and trim visible fat. 3. Limit high-potassium fruits like bananas and replace with apples or berries. 4. Ensure sodium intake stays under 2,000 mg per day. 5. Avoid processed foods high in sodium. 6. Keep fluid intake to 2.5 liters or less daily.<｜end▁of▁sentence｜>

# %%
new_model_local = "DeepSeek-R1-GMDT-Qwen-COT"
model.save_pretrained(new_model_local)
tokenizer.save_pretrained(new_model_local)

model.save_pretrained_merged(new_model_local, tokenizer, save_method = "merged_16bit",)
# Out:
# Unsloth: You have 1 CPUs. Using `safe_serialization` is 10x slower.
# We shall switch to Pytorch saving, which might take 3 minutes and not 30 minutes.
# To force `safe_serialization`, set it to `None` instead.
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 1.8G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 4.47 out of 12.67 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
# 100%|██████████| 28/28 [00:00<00:00, 30.99it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving DeepSeek-R1-GMDT-Qwen-COT/pytorch_model.bin...
# Done.

# %%
#### -------- PUSH TO HUB -------- ####
# new_model_online = "***/DeepSeek-R1-Test-COT"
# model.push_to_hub(new_model_online)
# tokenizer.push_to_hub(new_model_online)

# model.push_to_hub_merged(new_model_online, tokenizer, save_method = "merged_16bit")

# %%
! zip -r DeepSeek-R1-GMDT-Qwen-COT.zip DeepSeek-R1-GMDT-Qwen-COT/
# Out:
#   adding: DeepSeek-R1-GMDT-Qwen-COT/ (stored 0%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/adapter_config.json (deflated 55%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/tokenizer.json (deflated 81%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/special_tokens_map.json (deflated 70%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/config.json (deflated 50%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/tokenizer_config.json (deflated 84%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/pytorch_model.bin (deflated 12%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/README.md (deflated 66%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/adapter_model.safetensors (deflated 8%)
#   adding: DeepSeek-R1-GMDT-Qwen-COT/generation_config.json (deflated 37%)

# %%
import pandas as pd


df = pd.read_excel("GDMT data stacked KRYMAI.xlsx")
df.dropna(subset=["diet_history", "follow_up_recommendations"], inplace=True)
questions = df["diet_history"].values.tolist()
followup_recommendations = df["follow_up_recommendations"].values.tolist()
recommendations = []

for q in questions:
  inputs = tokenizer([prompt_style.format(q, "")], return_tensors="pt").to("cuda")

  outputs = model.generate(
      input_ids=inputs.input_ids,
      attention_mask=inputs.attention_mask,
      max_new_tokens=1200,
      use_cache=True,
  )
  response = tokenizer.batch_decode(outputs)
  print(f"Diet History: {q}")
  print(f"Recommendation: {response[0].split('### Response:')[1]}")
  recommendations.append(response[0].split("### Response:")[1])
  print("\n")


df_resp = pd.DataFrame()
df_resp["diet_history"] = questions
df_resp["actual_recommendations"] = followup_recommendations
df_resp["generated_recommendations"] = recommendations
df_resp.to_csv("trained_model_recommendations.csv", index=False)
# Out:
# Diet History: 9 am-gluten free bagel with peanut butter or salted butter or plain or frozen waffles/pancake-mix with real maple syrup or gluten-free oatmeal made with water plus brown sugar (1 TBSP) and berries 1300 hrs- cheese (2 slices of cheddar) or tuna sandwich plus dry apricots and 1 apple or gluten-free crackers with cheese or leftovers 5:50 pm-Fish with 2 cups rice with asparagus (6) and green beans (1 cup) or hamburger patty no bun and salad with prepared or homemade dressing or chicken breast (5 oz) with rice and vegs-1.5 cups (peppers, mushrooms, carrot, turnip, cabbage, tomatoes
# Recommendation:
# <think>
# Excessive sodium intake from processed or canned foods.
# </think>
# 1. Avoid processed meats and canned vegetables. 2. Limit high-potassium fruits like bananas or replace with apples or berries. 3. Ensure sodium intake stays under 2,000 mg per day.<｜end▁of▁sentence｜>
#
#
# Recommendation:
# <think>
# High sodium, saturated fat, potassium, and sugar intake.
# </think>
# 1. Use low-sodium soy sauce or other seasoning alternatives. 2. Limit sweet potatoes to 1/2 serving per day. 3. Choose low-potassium vegetables like cabbage or mustard greens. 4. Limit processed foods to keep sodium intake under 2,000 mg per day. 5. Read the nutrition facts table to optimize choices. 6. Use herbs and spices instead of salt.<｜end▁of▁sentence｜>
#
#
# Diet History: B: oatmeal crisp cereal with milk (1 cup each) or strawberry special k plus banana and 2 large tea-black L: sandwich-egg, luncheon meat, reg canned tuna or cucumber and mayo D:shake and bake chicken or Italian sausage (4 oz) or hot dogs with mashed potato (with cheese) and milk with corn/spinach/French green beans hs: tim bits/chocolate/choc bars/raisin bread or sandwich-banana-egg or luncheon meat
# Recommendation:
# <think>
# High sodium intake from processed foods,
# </think>
# 1. Limit processed meats and canned foods. 2. Choose low-potassium vegetables like zucchini and cabbage. 3. Read nutrition facts labels to monitor sodium content.<｜end▁of▁sentence｜>
#
#
# Diet History: B: coffee with coffeemate x 1 or lots of cream and stevia plus 500 ml water plus 2 slices bread with imperial margarine or instant brown sugar oatmeal plus one regular instant oatmeal OR original cheerios 1 cup and 1 cup 1% milk L: Salad with luncheon meat or luncheon and pickles or tomato, chicken and rice soup-homemade pm: rice cakes-caramel or white cheddar or diet jello with frozen berries and no fat cool whip or smart pop-orville reddenbacher D: cauliflower rice with chicken (boxed chx)or sausage or ground chx with fajita powder package in a lettuce wrap hs: 1 bag popcorn 4X 500 ml bottles of water per day
# Recommendation:
# <think>
# High sodium intake from processed foods.
# </think>
# 1. Avoid processed meats and canned foods with added sodium. 2. Choose fresh vegetables and fruits that are low in potassium. 3. Limit regular sodium intake to under 2,000 mg per day. 4. Drink no more than 2 liters of fluid per day.<｜end▁of▁sentence｜>
#
#
# Diet History: B: 1 slice ww bread with cream cheese or hummus or oatmeal made with water with vegs and chicken/beef/pork am: 1 slice bread with hummus (1/4-1/2 c) L: soup- 2 cups with lots of vegetables and chicken (with potatoes) or potatoes with chicken/beef with broccoli and carrots D; Soupd or bread (slices) with sausage or cream cheese or hummus and 1 fruit (usually apple)
# Recommendation:
# <think>
# Potential high sodium and potassium intake.
# </think>
# 1. Limit sodium to 1 tsp of salt per day. 2. Use olive oil and lemon juice for salad dressing instead of store-bought dressings high in sodium. 3. Limit potassium-rich foods like bananas or potatoes. 4. Read the nutrition facts table to optimize choices.<｜end▁of▁sentence｜>
#
#
# Diet History: B: 1/2 coffee and 1/2 homogenized milk with no sugar plus cheese sandwich most often or butter and jam or scrambled eggs am: 1/2-1/2 cup nuts with dates or an apple L: various stews, usually red meat with white rice and salad and yogurt (1 cup) pm: black tea-0 added plus cookies/cake plus nuts plus fruit (apple or nectarines) D: salad with tuna or most often a chicken salad or omelet with eggplant
# Recommendation:
# <think>
# Excessive sodium intake from processed foods.
# </think>
# 1. Avoid processed meats or canned foods high in sodium. 2. Limit potassium-rich vegetables like tomatoes and potatoes. 3. Maintain fluid intake to 2.5 liters or less.<｜end▁of▁sentence｜>
#
#
# Diet History: Pub food 2 times per month
# Recommendation:
# <think>
# Potential high sodium and moderate saturated fat intake.
# </think>
# 1. Limit pub foods. 2. Choose low-potassium vegetables. 3. Read nutrition facts labels.<｜end▁of▁sentence｜>
#
#
# Diet History: B: fruit-1 apple; occ 1 slice of bread with pb and Becel marg. recently d/c bananas L: s/w-ww bread with walmart luncheon meat-turkey, chx or ham-2 slices with mayo or relish or cheese (swiss/cheddar) slice D; fish and chips (from M&M) or pasta with tomato sauce and ground meat or roast beef with baked potato hs: sugar-free jello with low fat cool whip
# Recommendation:
# <think>
# High sodium, saturated fat, and potential potassium intake from potato chips.
# </think>
# 1. Use unsalted butter or olive oil when cooking. 2. Use low-sodium sauces and avoid processed foods. 3. Limit high-potassium vegetables like potato chips to 1/2 cup. 4. Read the nutrition facts table to optimize choices. 5. Use herbs and spices instead of salt.<｜end▁of▁sentence｜>
#
#
# Diet History: B: soda stream-unflav (840 ml x 3 per day) plus 2 plus cups of a blood orange juice plus 1-2 cups of dorset muesli with 1 cup unflv soy milk-silk and 1-2 cups of plain greek yogurt with pecans L:smoothie- New Zealand schinoussa protein powder with 1-2 cups unfl soy milk and 1 banana plus 1/4 cup walnuts and 1/2 apple and berries and 1 scoop of almond butter pm: cliff bars or 1/2 avocado and/or cheese, crackers (low potassium) and apple Dinner: Lebanese takeout 3-4 times per week (grilled chicken with tabbouleh, lentils, chickpeas plus hummus and pickles)
# Recommendation:
# <think>
# Excessive fat intake due to high use of tabbouleh and almond butter.
# </think>
# 1. Limit tabbouleh to 1/2 cup per day. 2. Use olive oil sparingly (1 tbsp per meal). 3. Drink no more than 2 liters of fluid daily. 4. Avoid high-potassium fruits like bananas and oranges.<｜end▁of▁sentence｜>
#
#
# Diet History: B: Cinnamon bagel with pB or 2 eggs-poached with 1/2 cup lentils and 1 slice tomato and lettuce on a bagel or cornmeal made with water plus 2% milk and brown sugar. 1/2 banana q other day plus orange pekoe or mint tea with 1/2 tsp sugar L: dumplings, steamed fish and brown yam Or pumpkin soup or stew with dumplings or chx feet/breast or cheese on a bun/bagel plus lime jce and brown sugar drink D: minced beef with potatoes and carrots (baked) hs: lots of nuts and a smoothie ( strawberries, 1/2 apple, 2 kiwis, 1/4 banana and oats with water/milk)
# Recommendation:
# <think>
# Potential high sodium and potassium intake, monitor sodium and fat.
# </think>
# 1. Use low-sodium cheese and sauce. 2. Limit added sugar. 3. Choose low-potassium vegetables. 4. Read nutrition facts labels.<｜end▁of▁sentence｜>
#
#
# Diet History: "tends to be an over-eater; these changes are from 1 week ago" 8:30-coffee with little milk; toast, white x 2 with becel no salt; mandarin orange 1 time per week L: haddock with 1/2 cup mixed veg and 1/2 c blueberries or no yolk pasta with parmesan dinner: salad plus same as lunchh 7:30 unsweetened applesauce D/c tomato products, potatoes, mushrooms and potato chips
# Recommendation:
# <think>
# Potential high sugar and moderate sodium intake, monitor potassium.
# </think>
# 1. Limit processed foods. 2. Choose low-potassium vegetables. 3. Read nutrition facts labels.<｜end▁of▁sentence｜>
#
#
# Diet History: B: roti with vegetable (spinach and onion) curry with tea (milk and brown sugar) L: roti (white) with curry and daal (with potato) D: rarely rice but a curry (potatoes, cauliflower) and tomatoes. salad (lettuce and cucumber) with no dressing hs: apple patient d/c rice recently
# Recommendation:
# <think>
# Potential high sodium and potassium intake.
# </think>
# 1. Limit high-potassium vegetables like potato to 1/2 cup per day. 2. Use unsalted butter or olive oil for cooking. 3. Choose lean proteins like chicken and turkey. 4. Read nutrition facts labels for sodium content.<｜end▁of▁sentence｜>
#
#
# Diet History: B: toasted bacon and cheese on light rye or fried egg and cheese on rye plus 2 tea with little 2% milk (not measured) L: subway-12" turkey sub or homemade soup (ex: dill pickle, chx with veg or pea) occ with a salami s/w D; read meat (6 oz) with salad
# Recommendation:
# <think>
# Excessive sodium intake from processed foods.
# </think>
# 1. Avoid processed meats and canned foods with added sodium. 2. Choose fresh vegetables and fruits that are low in potassium. 3. Limitzean or low-sodium seasonings.<｜end▁of▁sentence｜>
#
#
# Diet History: 8:30: 2 large coffees with cream and sugar (white) B: poached eggs x 2, 2 slices light rye with becel olive oil margarine, 350 ml v8 juice and 250 ml water OR 2 cups m/g cheerios and 1.2 cups 1% milk L: campbell's beef and barley soup (1 can) or habitant pea soup (1 can) with bologna s/w or leftover roast s/w D: chicken breast with shake 'n bake or marinated in milk with brussel sprouts and carrots. I glass of chocolate milk. snacks: yogurt with berries; pastry daily-apple fritter or chocolate banana cream pie, Haagen Daz ice cream
# Recommendation:
# <think>
# High sodium, saturated fat, and potential potassium intake from apple juice.
# </think>
# 1. Use unsalted butter. 2. Use low-sodium dietors. 3. Limit apple juice to 1/2 cup. 4. Choose low-potassium vegetables. 5. Read the nutrition facts table to optimize choices.<｜end▁of▁sentence｜>
#
#
# Diet History: 6 am: 2 eggs, 1 slice bacon and occ 1 slice bread-brown; 2 coffees (lots of cream and 2 tsp sugar per mug) throughout the day-10 oz AJ and 500 ml water dinner: tomatoes with steak/chicken (6 oz) plus big salad and mushrooms (cooked) evening: large bag of doritos every 2-3 days
# Recommendation:
# <think>
# Excessive potassium intake from bacon and tomatoes.
# </think>
# 1. Limit bacon to 1 slice per day. 2. Limit tomatoes to 1/2 small tomato per day. 3. Replace high-potassium vegetables with cucumber or zucchini.<｜end▁of▁sentence｜>
#
#
# Diet History: B: coffee and crumpet with marg (1 tbsp.) or bagel and marg L; s/w with turkey or ham (luncheon meat) plus 1 slice of cheese and lettuce. water D: veg and sausage stew or BBQ steak or chx with vegs NO Snacks except for fruit ( 2/day). Loves tomatoes, potatoes (white and sweet)
# Recommendation:
# <think>
# High sodium and saturated fat intake, monitor potassium.
# </think>
# 1. Limit processed meats. 2. Choose low-potassium vegetables. 3. Read nutrition facts labels.<｜end▁of▁sentence｜>
#
#
# Diet History: B: water plus 2 soft boiled eggs with pepper and bread and sunflower butter or OJ (8oz) plus apple and coconut yogurt am: high fibre bar made with honey at local coffee shop with 1 coffee with a little cream L: salad now with chicken or pork chop or pizza made with a pita bread with low sodium pizza sauce with no cheese and with veggies D: leftovers from lunch or pasta with meat sauce and tomato sauce hs/midnight: oranges
# Recommendation:
# <think>
# Excessive sodium intake from processed foods.
# </think>
# 1. Avoid processed meats and canned foods with added sodium. 2. Choose fresh vegetables and fruits that are low in potassium. 3. Limit salt in cooking; use herbs like rosemary, thyme, and basil instead.<｜end▁of▁sentence｜>
#
#
 4. Read nutrition facts labels.<｜end▁of▁sentence｜>
#
#
# Diet History: B: Cheerios with skim milk, 1/2 banana and 12 assorted berries and one coffee. L: 8 oz milk, 2 slices of bread with cheese and 1 apple D: salad and steak or meat loaf with mac and cheese. Dad's oatmeal cookies. Various vegetables and fruit consumed. Yogurt, milk and ice cream consumed.Juice is rare. Peanuts consumed
# Recommendation:
# <think>
# Excessive potassium intake from Cheees and bananas.
# </think>
# 1. Limit Cheees to 1/4 per day. 2. Reduce bananas to 1/2 banana per day. 3. Avoid added salt when seasoning.<｜end▁of▁sentence｜>
#
#
# Diet History: White rice plus scrambled eggs or 1/2 bagel or 1-2 slices of bread with becel margarine +/- jam L: steamed rice with vegetables (frozen spinach, okra, eggplant, etc) with 3 oz fish or chicken and occ red meat or legumes. D is similar to lunch. Snacks include fruit, nuts, pumpkin pie, ice cream, unsalted saltines, chocolate.
# Recommendation:
# <think>
# Excessive potassium intake from high-potassium fruits like bananas and potatoes.
# </think>
# 1. Limit bananas and potatoes to 1/2 serving per day. 2. Choose low-sodium seasoning and fresh vegetables. 3. Avoid high-sodium canned soups and opt for homemade soups.<｜end▁of▁sentence｜>
#
#
# Diet History: Food Intake Diet History / Food Recall: B: 250 ml coffee with 10% cream and sometimes honey with 1 egg and 1 slice white bread with EVOO and oregano or becel margarine. L: leftovers from the night before or low sodium canned tuna with a large salad or a Swiss cheese sandwich. D: 5 oz meat, fish or chicken with vegetables (variety) with rice/quinoa/pasta, etc. No snacks at the current time. Was having lots of Greek yogurt with berries but has not reduced to 3 tbsp. walnuts and pistachios have also been reduced.
# Recommendation:
# <think>
# Potential high sodium and potassium intake, monitor sodium and fat.
# </think>
# 1. Limit coffee to 250 ml. 2. Use skim or 1% milk instead of whole milk. 3. Choose low-potassium vegetables like bell peppers or zucchini. 4. Limit added salt. 5. Read nutrition facts labels.<｜end▁of▁sentence｜>
#
#
# Diet History: Food Intake Diet History / Food Recall: B: turkey (lunchoeon meat-5 slices from a deli with tomatoes and mustard) on Italian bun or a bagel with cheese and tomato (homemade) or McDonalds-sausage and egg mcmuffin with a regular coffee L: skips D: everything on it pizza at 5-6 slices of a medium(3 times per week) with coke-regular (2 Litres over 3 days) or Swiss Chalet (1/4 chicken with baked potato). 10 cans of coors light at once per month. No fruit or vegetables. Used to cook all of his food but is now having prepared/fast food
# Recommendation:
# <think>
# High sodium intake from processed foods, potential potassium from tomato based foods.
# </think>
# 1. Limit processed foods. 2. Limit high-potassium vegetables like tomatoes to 1/2 cup per day. 3. Use herbs and spices instead of salt. 4. Read the nutrition facts table to optimize choices.<｜end▁of▁sentence｜>
#
#
# Diet History: Diet History / Food Recall: B from 7:30-11: bagel-sesame seed or wholegrain or 2 slices of bread w/g with margarine-original or oatmeal-instant and flavoured (3 packets) or kuerig coffee (changed from triple-triple to double-double) skips lunch D from 4:30-6:30: pork chops/poultry or fish with vegetables and potato or rice; used to have dishes with hollandaise sauce/alfredo sauce. Recently d/c oranges, bananas to lower potassium and has reduced salt-used to salt food without first tasting it and d/c mac and cheese. Has 3-4 fruits per day. evening: jell-o or juice (mango nectar) or corn chips with salsa or yogurt 2400 g per week. One litre of milk per day. Patient has reduced fast food/take out
# Recommendation:
# <think>
# Potential moderate sodium intake, monitor potassium.
# </think>
# 1. Use low-sodium sauces and avoid processed foods. 2. Limit corn chips to 1/4 cup per week. 3. Use herbs and spices instead of salt.<｜end▁of▁sentence｜>
#
#
# Recommendation:
# <think>
# Excessive sodium intake from processed foods.
# </think>
# 1. Avoid processed foods and choose fresh ingredients. 2. Limit potassium-rich vegetables like tomatoes to 1/2 cup per day. 3. Opt for low-sodium alternatives for canned tuna.<｜end▁of▁sentence｜>
#
#
# Diet History: B: raisin bran or quaker harvest crunch cereal or instant oatmeal-maple brown sugar with 2% milk am: keureg hot chocolate and nature valley grain bar or i mini pack of fruit sensations gummies no processed food; occasionally 100 g oikos fruit bottom yogurt L: tuna (low sodium) with mayo on ww sandwich plus cucumber plus 7 cherry tomatoes with cucumber salad dressing for dipping and 1/2 cup sweet potatoes-1 tsp of milk and brown sugar or tomato soup with 6 ww crackers or homemade chicken soup D: chicken (3 oz) with bean medly (canned/low sodium) and 1/2 cup sliced beets. no evening snacks; eating out is rare; 3 fruits per day
# Recommendation:
# <think>
# Potential high sodium intake, monitor potassium.
# </think>
# 1. Limit canned or low-sodium fruits like bananas or oranges. 2. Use herbs like basil, and avoid salt. 3. Read nutrition facts labels.<｜end▁of▁sentence｜>
#
#
# Diet History: Diet History / Food Recall: B: bagel with butter and or sliced bread with banana and pb or cereal- a mix of cheerios/shreddies/bran buds with milk and raisins L: skips 5/7 times out of the week; if he does have lunch then sliced deli meat with 2 slices of w/g bread with mustard pm: green tea D: chicken with potatoes and vegetables-carrots/broccoli/cauliflower/green beans or fish with fries or rice or pasta with tomato sauce; snacks; 1-2 serving of fruit/d (apple, berries, bananas, raisins); evening snack- cadbury fruit and nut chocolate bar; 2 oreo cookies with tea
# Recommendation:
# <think>
# Potential high sodium and potassium intake.
# </think>
# 1. Limit processed meats like deli meats. 2. Use low-sodium or skim milk instead of whole milk. 3. Choose low-potassium vegetables like carrots and green beans. 4. Limit added salt. 5. Read the nutrition facts table to optimize choices. 6. Use herbs and spices instead of salt.<｜end▁of▁sentence｜>
#
#
# Diet History: Diet History / Food Recall: B: cereal (fibre 1-unsweetened) with almond milk or porridge made with water and adds milk with berries plus 1 slice m/g rudolph's bread with almond butter and jam plus coffee-black no sugar or french toast made with challa with berries L: tuna sandwich with mayo or 1/2 cup bean medley with salad; pm: green apple with cheddar cheese or 1/2 cup mixed nuts D: salmon or trout or chicken-no skin with carrots and broccoli EVOO or canola oil; makes her own mandelbread
# Recommendation:
# <think>
# Excessive sodium intake from salted butter or frequent consumption of processed foods.
# </think>
# 1. Use unsalted butter or eliminate it from meals. 2. Limit high-potassium fruits like bananas and oranges. 3. Drink no more than 2.5 liters of fluid per day. 4. Avoid processed meats and canned foods with added sodium.<｜end▁of▁sentence｜>
#
#
# Diet History: B: 3/4 tea with (1/4) 2% milk; 1 cup of 2% milk with meds; 9:30-cereal-corn flakes with or oats made water-then adds 2 tsp sugar-white and milk L: Loves sweets-chocloate or cookies or candies but no other food D at 7 pm: fish or beef curry with vegetables with white basmati rice plus ice cream; 1 apple -1/2; if unable to sleep than has a glass of warm milk
# Recommendation:
# <think>
# Potential high sugar and moderate sodium intake, monitor potassium.
# </think>
# 1. Limit high-potassium fruits like oranges or bananas. 2. Choose low-potassium vegetables. 3. Use herbs and spices instead of salt. 4. Read nutrition facts labels.<｜end▁of▁sentence｜>

# %%
df_resp.head()

# %%
len(df)
# Out:
# 47

# %%
! pip install textstat rouge-score
# Out:
# Collecting textstat
#   Downloading textstat-0.7.5-py3-none-any.whl.metadata (15 kB)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting cmudict (from textstat)
#   Downloading cmudict-1.0.32-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from textstat) (75.1.0)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (8.6.1)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=5->cmudict->textstat) (3.21.0)
# Downloading textstat-0.7.5-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 6.6 MB/s eta 0:00:00
# Downloading cmudict-1.0.32-py3-none-any.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.4/939.4 kB 31.2 MB/s eta 0:00:00
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 62.7 MB/s eta 0:00:00
# Installing collected packages: pyphen, cmudict, textstat
# Successfully installed cmudict-1.0.32 pyphen-0.17.2 textstat-0.7.5

# %%
import math
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from textstat.textstat import textstat
from sklearn.metrics import precision_recall_fscore_support
from transformers import pipeline

# Ensure nltk is properly downloaded
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# 1. Precision, Recall, F1-Score (Token-level calculation)
def precision_recall_f1(generated_text, reference_text):
    generated_tokens = nltk.word_tokenize(generated_text.lower())
    reference_tokens = nltk.word_tokenize(reference_text.lower())

    # True positives: Tokens in both reference and generated texts
    true_positives = sum(1 for token in generated_tokens if token in reference_tokens)

    # False positives: Tokens in generated text but not in reference text
    false_positives = sum(1 for token in generated_tokens if token not in reference_tokens)

    # False negatives: Tokens in reference text but not in generated text
    false_negatives = sum(1 for token in reference_tokens if token not in generated_tokens)

    # Calculate Precision, Recall, F1
    if true_positives + false_positives == 0:
        precision = 0
    else:
        precision = true_positives / (true_positives + false_positives)

    if true_positives + false_negatives == 0:
        recall = 0
    else:
        recall = true_positives / (true_positives + false_negatives)

    if precision + recall == 0:
        f1 = 0
    else:
        f1 = 2 * (precision * recall) / (precision + recall)

    return precision, recall, f1


# 2. BLEU Score
def bleu_score(reference_text, generated_text):
    reference_tokens = nltk.word_tokenize(reference_text.lower())
    generated_tokens = nltk.word_tokenize(generated_text.lower())

    # Using smoothing function to avoid zero BLEU scores
    smoothing_function = SmoothingFunction().method1
    return sentence_bleu([reference_tokens], generated_tokens, smoothing_function=smoothing_function)


# 3. ROUGE Score
def rouge_score_fn(reference_text, generated_text):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference_text, generated_text)
    return scores


# 4. Perplexity Score (for Language Model)
def perplexity(generated_text):
    # Tokenize and compute perplexity using a simple unigram model
    tokens = nltk.word_tokenize(generated_text.lower())
    unique_tokens = set(tokens)
    token_count = len(tokens)

    # Compute unigram probabilities
    probabilities = [tokens.count(token) / token_count for token in unique_tokens]
    entropy = -sum([p * math.log2(p) for p in probabilities])
    return math.pow(2, entropy)


# 5. Flesch-Kincaid Readability Score
def flesch_kincaid_readability(generated_text):
    return textstat.flesch_kincaid_grade(generated_text)


# 6. Entropy
def entropy(generated_text):
    # Tokenize the text and compute entropy
    tokens = nltk.word_tokenize(generated_text.lower())
    token_count = len(tokens)
    token_frequencies = {token: tokens.count(token) / token_count for token in set(tokens)}
    entropy_value = -sum([p * math.log2(p) for p in token_frequencies.values()])
    return entropy_value

# %%
p, r, f, bleu, rogue1, rogue2, rogueL, pp, fk, ent = [], [], [], [], [], [], [], [], [], []
for reference_text, generated_text in zip(followup_recommendations[1:], recommendations[1:]):
    s = precision_recall_f1(generated_text, reference_text)
    p.append(s[0])
    r.append(s[1])
    f.append(s[2])

    bleu.append(bleu_score(reference_text, generated_text))
    s = rouge_score_fn(reference_text, generated_text)
    rogue1.append(s['rouge1'].fmeasure)
    rogue2.append(s['rouge2'].fmeasure)
    rogueL.append(s['rougeL'].fmeasure)

    pp.append(perplexity(generated_text))
    fk.append(flesch_kincaid_readability(generated_text))
    ent.append(entropy(generated_text))

# %%
print(f"""
Trained Qwen-1B recommendation performance:
      \n Precision: {round(sum(p)/len(p), 4)}, Recall: {round(sum(r)/len(r), 4)}, F1-score: {round(sum(f)/len(f), 4)}
      \n BLEU Score: {round(sum(bleu)/len(bleu), 4)}, ROGUE-1: {round(sum(rogue1)/len(rogue1), 4)}, ROGUE-2: {round(sum(rogue2)/len(rogue2), 4)}, ROGUE-L: {round(sum(rogueL)/len(rogueL), 4)}
      \n Perplexity: {round(sum(pp)/len(pp), 4)}, Flesch-Kincaid Readability Grade: {round(sum(fk)/len(fk), 4)}, Entropy: {round(sum(ent)/len(ent), 4)}
""")
# Out:
# Trained Qwen-1B recommendation performance:
#
#  Precision: 0.2727, Recall: 0.2484, F1-score: 0.2445
#
#  BLEU Score: 0.0161, ROGUE-1: 0.2835, ROGUE-2: 0.0521, ROGUE-L: 0.1779
#
#  Perplexity: 36.0484, Flesch-Kincaid Readability Grade: 8.7043, Entropy: 5.1414

# %% [markdown]
# # Comparing to the performance without SFT

# %%
question = "9:00 AM - Grits with butter, 1:00 PM - Fried chicken with collard greens, 7:00 PM - Sweet potato pie."
FastLanguageModel.for_inference(model_og)


wo_sft_recommendation = []
for q in questions:
  inputs = tokenizer([prompt_style.format(q, "")], return_tensors="pt").to("cuda")

  outputs = model_og.generate(
      input_ids=inputs.input_ids,
      attention_mask=inputs.attention_mask,
      use_cache=True
  )
  response = tokenizer.batch_decode(outputs)
  print(f"Diet History: {q}")
  print(f"Recommendation: {response[0].split('### Response:')[1]}")
  wo_sft_recommendation.append(response[0].split("### Response:")[1])
  print("\n")

df_resp = pd.DataFrame()
df_resp["diet_history"] = questions
df_resp["actual_recommendations"] = followup_recommendations
df_resp["generated_recommendations_wo_sft"] = wo_sft_recommendation
df_resp.to_csv("wo_sft_model_recommendations.csv", index=False)

# %%
p, r, f, bleu, rogue1, rogue2, rogueL, pp, fk, ent = [], [], [], [], [], [], [], [], [], []
for reference_text, generated_text in zip(followup_recommendations[1:], wo_sft_recommendation[1:]):
    s = precision_recall_f1(generated_text, reference_text)
    p.append(s[0])
    r.append(s[1])
    f.append(s[2])

    bleu.append(bleu_score(reference_text, generated_text))
    s = rouge_score_fn(reference_text, generated_text)
    rogue1.append(s['rouge1'].fmeasure)
    rogue2.append(s['rouge2'].fmeasure)
    rogueL.append(s['rougeL'].fmeasure)

    pp.append(perplexity(generated_text))
    fk.append(flesch_kincaid_readability(generated_text))
    ent.append(entropy(generated_text))

# %%
print(f"""
OOB Qwen-1B recommendation performance:
      \n Precision: {round(sum(p)/len(p), 4)}, Recall: {round(sum(r)/len(r), 4)}, F1-score: {round(sum(f)/len(f), 4)}
      \n BLEU Score: {round(sum(bleu)/len(bleu), 4)}, ROGUE-1: {round(sum(rogue1)/len(rogue1), 4)}, ROGUE-2: {round(sum(rogue2)/len(rogue2), 4)}, ROGUE-L: {round(sum(rogueL)/len(rogueL), 4)}
      \n Perplexity: {round(sum(pp)/len(pp), 4)}, Flesch-Kincaid Readability Grade: {round(sum(fk)/len(fk), 4)}, Entropy: {round(sum(ent)/len(ent), 4)}
""")
